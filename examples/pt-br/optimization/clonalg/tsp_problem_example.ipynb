# %% [markdown]
# # Otimização com o Algoritmo de Seleção Clonal (CLONALG)
#
# ## 1. Introdução
#
# ### Problema do Caixeiro Viajante (TSP)
#
# Neste notebook, aplica o ClonAlg ao **Problema do Caixeiro Viajante (Traveling Salesman Problem - TSP)**.
#
# O problema consiste em encontrar o caminho mais curto que visita cada cidade exatamente uma vez e retorna à cidade de origem.

# %% [markdown]
# ## 2. Configuração
#
# ### Instalação das bibliotecas necessários.

# %%
# %pip install matplotlib
# %pip install networkx
# %pip install aisp
# %pip install scipy

# %% [markdown]
# ### Importação das bibliotecas necessárias

# %%
# Importando o Algoritmo de Seleção Clonal (CLONALG)
from aisp.csa import Clonalg

# Bibliotecas para manipulação de dados e cálculos numéricos
import numpy as np
import random
from itertools import combinations
from scipy.spatial import distance

# Visualização de dados
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# ## 3. Definição do problema
#
# Cria 15 cidades com coordenadas aleatórias e define a função ``tsp_fitness``.

# %%
# Configuração do problema
n_cities = 15
cities = []
random.seed(123)

# Gerar coordenadas aleatórias para as cidades
for i in range(n_cities):
    x = random.uniform(0, 100)
    y = random.uniform(0, 100)
    cities.append((x, y))

cities = np.array(cities)

# Função de fitness para TSP
def tsp_fitness(solution):
    total_distance = 0
    n = len(solution)

    for i in range(n):
        current_city = cities[solution[i]]
        next_city = cities[solution[(i + 1) % len(solution)]]
        total_distance += distance.euclidean(current_city, next_city)
    return total_distance

print(f"Número de cidades: {n_cities}")
print("Coordenadas das cidades:")
for i, city in enumerate(cities):
    print(f"Cidade {i}: ({city[0]:.2f}, {city[1]:.2f})")
# Out:
# Número de cidades: 15
# Coordenadas das cidades:
# Cidade 0: (5.24, 8.72)
# Cidade 1: (40.72, 10.77)
# Cidade 2: (90.12, 3.82)
# Cidade 3: (53.62, 33.22)
# Cidade 4: (85.21, 15.97)
# Cidade 5: (33.72, 33.38)
# Cidade 6: (24.52, 0.17)
# Cidade 7: (43.63, 8.76)
# Cidade 8: (59.76, 6.99)
# Cidade 9: (31.55, 44.83)
# Cidade 10: (90.54, 9.28)
# Cidade 11: (14.22, 79.01)
# Cidade 12: (2.12, 91.12)
# Cidade 13: (57.34, 26.53)
# Cidade 14: (83.78, 76.88)

# %% [markdown]
# ## 4. Configuração do algoritmo

# %%
clonalg = Clonalg(
    problem_size=n_cities,
    N=100,
    selection_size=15,
    rate_clonal=30,
    rate_hypermutation=3,
    n_diversity_injection=20,
    feature_type="permutation-features",
    seed=121
)

clonalg.register('affinity_function', tsp_fitness)

# %% [markdown]
# ## 5. Execução da otimização

# %%
clonalg.optimize(500, 20)

if clonalg.best_cost is not None:
    print('Melhor distância encontrada:', clonalg.best_cost)
    print('Melhor rota:', clonalg.best_solution)
# Out:
# ┌───────────┬─────────────────────────┬────────────────────┬─────────────────┐
# │ Iteration │   Best Affinity (min)   │   Worse Affinity   │   Stagnation    │
# ├───────────┼─────────────────────────┼────────────────────┼─────────────────┤
# │     1     │               603.855687│          823.417601│        0        │
# │     2     │               560.431577│          656.611307│        0        │
# │     3     │               541.960409│          764.707134│        0        │
# │     4     │               514.734954│          833.599923│        0        │
# │     5     │               503.850059│          750.053442│        0        │
# │     6     │               495.427273│          798.079603│        0        │
# │     7     │               472.914431│          908.857603│        0        │
# │     8     │               449.949200│          853.719843│        0        │
# │     9     │               449.949200│          855.685675│        1        │
# │    10     │               429.920551│          912.292224│        0        │
# │    11     │               429.920551│          750.434604│        1        │
# │    12     │               422.582390│          874.650979│        0        │
# │    13     │               422.582390│          795.747316│        1        │
# │    14     │               416.450778│          711.255326│        0        │
# │    15     │               416.450778│          867.374772│        1        │
# │    16     │               409.495211│          931.129509│        0        │
# │    17     │               409.495211│          879.775709│        1        │
# │    18     │               386.188614│          878.645062│        0        │
# │    19     │               382.955484│          709.814715│        0        │
# │    20     │               382.955484│          872.456476│        1        │
# │    21     │               382.955484│          894.141367│        2        │
# │    22     │               382.955484│          896.157782│        3        │
# │    23     │               382.955484│          754.977998│        4        │
# │    24     │               382.955484│          823.318120│        5        │
# │    25     │               382.955484│          907.760557│        6        │
# │    26     │               382.955484│          877.735384│        7        │
# │    27     │               382.955484│          797.917870│        8        │
# │    28     │               382.955484│          876.039722│        9        │
# │    29     │               382.955484│          706.134882│       10        │
# │    30     │               382.955484│          895.569424│       11        │
# │    31     │               382.955484│          867.881796│       12        │
# │    32     │               382.955484│          797.955601│       13        │
# │    33     │               382.955484│          831.915884│       14        │
# │    34     │               382.955484│          754.713913│       15        │
# │    35     │               382.955484│          876.608282│       16        │
# │    36     │               382.955484│          842.595915│       17        │
# │    37     │               382.955484│          768.355538│       18        │
# │    38     │               382.955484│          807.436943│       19        │
# │    39     │               382.955484│          844.502325│       20        │
# └───────────┴─────────────────────────┴────────────────────┴─────────────────┘
# Total time: 2.064918 seconds
# Melhor distância encontrada: 382.9554837815304
# Melhor rota: [12 11  9  5  0  6  1  7  8  2 10  4 13  3 14]

# %% [markdown]
# ## 6. Resultado

# %%
print(clonalg.get_report())
# Out:
# =============================================
#             Optimization Summary
# =============================================
# Best cost      : 382.9554837815304
# Best solution  : [12 11  9  5  0  6  1  7  8  2 10  4 13  3 14]
# Cost History per Iteration:
#
# ┌────────────┬────────────────────────────┐
# │ Iteration  │            Cost            │
# ├────────────┼────────────────────────────┤
# │          1 │                 603.855687 │
# │          2 │                 560.431577 │
# │          3 │                 541.960409 │
# │          4 │                 514.734954 │
# │          5 │                 503.850059 │
# │          6 │                 495.427273 │
# │          7 │                 472.914431 │
# │          8 │                 449.949200 │
# │          9 │                 449.949200 │
# │         10 │                 429.920551 │
# │         11 │                 429.920551 │
# │         12 │                 422.582390 │
# │         13 │                 422.582390 │
# │         14 │                 416.450778 │
# │         15 │                 416.450778 │
# │         16 │                 409.495211 │
# │         17 │                 409.495211 │
# │         18 │                 386.188614 │
# │         19 │                 382.955484 │
# │         20 │                 382.955484 │
# │         21 │                 382.955484 │
# │         22 │                 382.955484 │
# │         23 │                 382.955484 │
# │         24 │                 382.955484 │
# │         25 │                 382.955484 │
# │         26 │                 382.955484 │
# │         27 │                 382.955484 │
# │         28 │                 382.955484 │
# │         29 │                 382.955484 │
# │         30 │                 382.955484 │
# │         31 │                 382.955484 │
# │         32 │                 382.955484 │
# │         33 │                 382.955484 │
# │         34 │                 382.955484 │
# │         35 │                 382.955484 │
# │         36 │                 382.955484 │
# │         37 │                 382.955484 │
# │         38 │                 382.955484 │
# │         39 │                 382.955484 │
# └────────────┴────────────────────────────┘

# %% [markdown]
# ### 6.1 Evolução do melhor ao longo das gerações

# %%
plt.figure(figsize=(10, 6))
plt.plot(clonalg.cost_history, marker='o', linewidth=2, markersize=4)
plt.title('Evolução da Distância ao Longo das Interações', fontsize=16)
plt.xlabel('Interações', fontsize=12)
plt.ylabel('Distância Total', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
def plot_all_routes_with_best(cities, best_route, title):
    G = nx.Graph()
    for i, (x, y) in enumerate(cities):
        G.add_node(i, pos=(x, y))
    all_edges = list(combinations(range(len(cities)), 2))
    G.add_edges_from(all_edges)
    
    # Adicionar arestas da melhor rota para destaque
    best_route_extended = list(best_route) + [best_route[0]]  # Fechar o ciclo
    best_edges = [(best_route_extended[i], best_route_extended[i+1]) for i in range(len(best_route_extended)-1)]
    
    pos = nx.get_node_attributes(G, 'pos')
    
    plt.figure(figsize=(12, 8))
    
    # Desenhar as arestas
    nx.draw_networkx_edges(G, pos, edgelist=all_edges, edge_color='lightgray', alpha=0.5)
    nx.draw_networkx_edges(G, pos, edgelist=best_edges, edge_color='blue', width=2)
    
    nx.draw_networkx_nodes(G, pos, node_size=300, node_color='red')
    
    nx.draw_networkx_labels(G, pos, font_size=12, font_color='black')
    
    plt.title(title, fontsize=16)
    plt.xlabel('X', fontsize=12)
    plt.ylabel('Y', fontsize=12)
    plt.grid(True, alpha=0.3)
    plt.axis('equal')
    plt.show()

if clonalg.best_solution is not None:
    plot_all_routes_with_best(cities, clonalg.best_solution, f'Melhor Rota Encontrada - (Distância Total: {clonalg.best_cost:.2f})')
